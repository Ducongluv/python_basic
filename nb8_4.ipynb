# %% [markdown]
# ## CSV 읽기 DictReader

# %%
import csv

with open("score.csv", "r", encoding="utf-8") as f:
    reader = csv.DictReader(f) # 헤드라인 키, 나머지 내용 값으로

    for row in reader:
        print(row)
# Out:
# {'이름': '홍길동', '나이': '20', '국어': '90', '영어': '85'}
# {'이름': '이순신', '나이': '21', '국어': '88', '영어': '90'}
# {'이름': '김유신', '나이': '', '국어': '95', '영어': '100'}
# {'이름': '강감찬', '나이': '22', '국어': '결측', '영어': '82'}
# {'이름': '유관순', '나이': '19', '국어': '100', '영어': '110'}
# {'이름': '안중근', '나이': '150', '국어': '85', '영어': '88'}
# {'이름': '윤봉길', '나이': '20', '국어': '-5', '영어': '91'}
# {'이름': '신사임당', '나이': '21', '국어': '92', '영어': ''}
# {'이름': '장보고', '나이': '18', '국어': '87', '영어': '89'}
# {'이름': '세종대왕', '나이': '23', '국어': '93', '영어': '94'}
# {'이름': '을지문덕', '나이': '20', '국어': '91', '영어': '86'}
# {'이름': '허준', '나이': '21', '국어': '89', '영어': '87'}
# {'이름': '김구', '나이': '22', '국어': '500', '영어': '92'}
# {'이름': '이황', '나이': '19', '국어': '84', '영어': '81'}
# {'이름': '이이', '나이': '20', '국어': '86', '영어': 'NaN'}
# {'이름': '정약용', '나이': '21', '국어': '90', '영어': '88'}
# {'이름': '논개', '나이': '22', '국어': '88', '영어': '85'}
# {'이름': '계백', '나이': '20', '국어': '', '영어': '84'}
# {'이름': '관우', '나이': '19', '국어': '97', '영어': '96'}
# {'이름': '장비', '나이': '20', '국어': '95', '영어': '-10'}

# %% [markdown]
# ## list(reader)

# %%
with open("score.csv", "r", encoding="utf-8") as f:
    reader = csv.DictReader(f) 

    data = list(reader)

print(data)
# Out:
# [{'이름': '홍길동', '나이': '20', '국어': '90', '영어': '85'}, {'이름': '이순신', '나이': '21', '국어': '88', '영어': '90'}, {'이름': '김유신', '나이': '', '국어': '95', '영어': '100'}, {'이름': '강감찬', '나이': '22', '국어': '결측', '영어': '82'}, {'이름': '유관순', '나이': '19', '국어': '100', '영어': '110'}, {'이름': '안중근', '나이': '150', '국어': '85', '영어': '88'}, {'이름': '윤봉길', '나이': '20', '국어': '-5', '영어': '91'}, {'이름': '신사임당', '나이': '21', '국어': '92', '영어': ''}, {'이름': '장보고', '나이': '18', '국어': '87', '영어': '89'}, {'이름': '세종대왕', '나이': '23', '국어': '93', '영어': '94'}, {'이름': '을지문덕', '나이': '20', '국어': '91', '영어': '86'}, {'이름': '허준', '나이': '21', '국어': '89', '영어': '87'}, {'이름': '김구', '나이': '22', '국어': '500', '영어': '92'}, {'이름': '이황', '나이': '19', '국어': '84', '영어': '81'}, {'이름': '이이', '나이': '20', '국어': '86', '영어': 'NaN'}, {'이름': '정약용', '나이': '21', '국어': '90', '영어': '88'}, {'이름': '논개', '나이': '22', '국어': '88', '영어': '85'}, {'이름': '계백', '나이': '20', '국어': '', '영어': '84'}, {'이름': '관우', '나이': '19', '국어': '97', '영어': '96'}, {'이름': '장비', '나이': '20', '국어': '95', '영어': '-10'}]

# %% [markdown]
# ## 결측치 처리

# %%
blank = 0
missing = 0
nan_Val = 0

for d in data:
    if d["나이"] == "":
        blank += 1
    elif d["국어"] == "":
        blank += 1
    elif d["영어"] == "":
        blank += 1
    else:
        continue

for d in data:
    if d["나이"] == "결측":
        missing += 1
    elif d["국어"] == "결측":
        missing += 1
    elif d["영어"] == "결측":
        missing += 1
    else:
        continue

for d in data:
    if d["나이"] == "NaN":
        nan_Val += 1
    elif d["국어"] == "NaN":
        nan_Val += 1
    elif d["영어"] == "NaN":
        nan_Val += 1
    else:
        continue

print("빈 문자열 개수 : ", blank)
print("결측 개수 : ", missing)
print("NaN 개수 : ", nan_Val)
# Out:
# 빈 문자열 개수 :  3
# 결측 개수 :  1
# NaN 개수 :  1

# %% [markdown]
# ### 나이 먼저 처리

# %%
# 나이 값 type 알아보기
for d in data:
    if d["나이"] != "":
        print(d["나이"])
        print(type(d["나이"]))
# Out:
# 20
# <class 'str'>
# 21
# <class 'str'>
# 22
# <class 'str'>
# 19
# <class 'str'>
# 150
# <class 'str'>
# 20
# <class 'str'>
# 21
# <class 'str'>
# 18
# <class 'str'>
# 23
# <class 'str'>
# 20
# <class 'str'>
# 21
# <class 'str'>
# 22
# <class 'str'>
# 19
# <class 'str'>
# 20
# <class 'str'>
# 21
# <class 'str'>
# 22
# <class 'str'>
# 20
# <class 'str'>
# 19
# <class 'str'>
# 20
# <class 'str'>

# %%
# 빈칸 제외 다 int로 type 형변환
for d in data:
    if d["나이"] != "":
        d["나이"] = int(d["나이"])

# %%
# 빈칸 제외 int로 형변환 된거 확인
for d in data:
    if d["나이"] != "":
        print(d["나이"])
        print(type(d["나이"]))
# Out:
# 20
# <class 'int'>
# 21
# <class 'int'>
# 22
# <class 'int'>
# 19
# <class 'int'>
# 150
# <class 'int'>
# 20
# <class 'int'>
# 21
# <class 'int'>
# 18
# <class 'int'>
# 23
# <class 'int'>
# 20
# <class 'int'>
# 21
# <class 'int'>
# 22
# <class 'int'>
# 19
# <class 'int'>
# 20
# <class 'int'>
# 21
# <class 'int'>
# 22
# <class 'int'>
# 20
# <class 'int'>
# 19
# <class 'int'>
# 20
# <class 'int'>

# %%
# 평균 구하기 -> 결측치 평균으로 대치
age_total = 0
age_count = 0

for d in data:
    if d["나이"] != "":
        age_total = age_total + d["나이"]
        age_count = age_count +1
avg = int(round(age_total / age_count,1))

print(age_total, age_count)
print(f"avg {avg}")

for d in data:
    if d["나이"] == "":
        d["나이"] = avg

data
# Out:
# 518 19
# avg 27
# [{'이름': '홍길동', '나이': 20, '국어': '90', '영어': '85'},
#  {'이름': '이순신', '나이': 21, '국어': '88', '영어': '90'},
#  {'이름': '김유신', '나이': 27, '국어': '95', '영어': '100'},
#  {'이름': '강감찬', '나이': 22, '국어': '결측', '영어': '82'},
#  {'이름': '유관순', '나이': 19, '국어': '100', '영어': '110'},
#  {'이름': '안중근', '나이': 150, '국어': '85', '영어': '88'},
#  {'이름': '윤봉길', '나이': 20, '국어': '-5', '영어': '91'},
#  {'이름': '신사임당', '나이': 21, '국어': '92', '영어': ''},
#  {'이름': '장보고', '나이': 18, '국어': '87', '영어': '89'},
#  {'이름': '세종대왕', '나이': 23, '국어': '93', '영어': '94'},
#  {'이름': '을지문덕', '나이': 20, '국어': '91', '영어': '86'},
#  {'이름': '허준', '나이': 21, '국어': '89', '영어': '87'},
#  {'이름': '김구', '나이': 22, '국어': '500', '영어': '92'},
#  {'이름': '이황', '나이': 19, '국어': '84', '영어': '81'},
#  {'이름': '이이', '나이': 20, '국어': '86', '영어': 'NaN'},
#  {'이름': '정약용', '나이': 21, '국어': '90', '영어': '88'},
#  {'이름': '논개', '나이': 22, '국어': '88', '영어': '85'},
#  {'이름': '계백', '나이': 20, '국어': '', '영어': '84'},
#  {'이름': '관우', '나이': 19, '국어': '97', '영어': '96'},
#  {'이름': '장비', '나이': 20, '국어': '95', '영어': '-10'}]

# %% [markdown]
# ## 국어 결측치 처리

# %%
for d in data:
    if d["국어"] != "":
        print(d["국어"])
        print(type(d["국어"]))
# Out:
# 90
# <class 'str'>
# 88
# <class 'str'>
# 95
# <class 'str'>
# 결측
# <class 'str'>
# 100
# <class 'str'>
# 85
# <class 'str'>
# -5
# <class 'str'>
# 92
# <class 'str'>
# 87
# <class 'str'>
# 93
# <class 'str'>
# 91
# <class 'str'>
# 89
# <class 'str'>
# 500
# <class 'str'>
# 84
# <class 'str'>
# 86
# <class 'str'>
# 90
# <class 'str'>
# 88
# <class 'str'>
# 97
# <class 'str'>
# 95
# <class 'str'>

# %%
# 국어는 빈칸과 "결측이 둘 다 있으므로 둘 다 제외 하고 형변환"
for d in data:
    if d["국어"] != "" and d["국어"] != "결측":
        d["국어"] = int(d["국어"])

# %%
# 빈칸 제외 int로 형변환 된거 확인
for d in data:
    if d["국어"] != "":
        print(d["국어"])
        print(type(d["국어"]))
# Out:
# 90
# <class 'int'>
# 88
# <class 'int'>
# 95
# <class 'int'>
# 결측
# <class 'str'>
# 100
# <class 'int'>
# 85
# <class 'int'>
# -5
# <class 'int'>
# 92
# <class 'int'>
# 87
# <class 'int'>
# 93
# <class 'int'>
# 91
# <class 'int'>
# 89
# <class 'int'>
# 500
# <class 'int'>
# 84
# <class 'int'>
# 86
# <class 'int'>
# 90
# <class 'int'>
# 88
# <class 'int'>
# 97
# <class 'int'>
# 95
# <class 'int'>

# %%
kor_total = 0
kor_count = 0

for d in data:
    # if d["국어"] != "" and d["국어"] != "결측":
    #     total += d["국어"]
    #     count += 1
    if d["국어"] != "" and d["국어"] != "결측":
        if 0 <= d["국어"] and d["국어"] <= 100:
            kor_total += d["국어"]
            kor_count += 1
print(kor_total, kor_count)
avg_kor = int(round(kor_total / kor_count,1))
print(avg_kor)

for d in data:
    if d["국어"] == "" or d["국어"] == "결측":
        d["국어"] = avg_kor

data
# Out:
# 1450 16
# 90
# [{'이름': '홍길동', '나이': 20, '국어': 90, '영어': '85'},
#  {'이름': '이순신', '나이': 21, '국어': 88, '영어': '90'},
#  {'이름': '김유신', '나이': 27, '국어': 95, '영어': '100'},
#  {'이름': '강감찬', '나이': 22, '국어': 90, '영어': '82'},
#  {'이름': '유관순', '나이': 19, '국어': 100, '영어': '110'},
#  {'이름': '안중근', '나이': 150, '국어': 85, '영어': '88'},
#  {'이름': '윤봉길', '나이': 20, '국어': -5, '영어': '91'},
#  {'이름': '신사임당', '나이': 21, '국어': 92, '영어': ''},
#  {'이름': '장보고', '나이': 18, '국어': 87, '영어': '89'},
#  {'이름': '세종대왕', '나이': 23, '국어': 93, '영어': '94'},
#  {'이름': '을지문덕', '나이': 20, '국어': 91, '영어': '86'},
#  {'이름': '허준', '나이': 21, '국어': 89, '영어': '87'},
#  {'이름': '김구', '나이': 22, '국어': 500, '영어': '92'},
#  {'이름': '이황', '나이': 19, '국어': 84, '영어': '81'},
#  {'이름': '이이', '나이': 20, '국어': 86, '영어': 'NaN'},
#  {'이름': '정약용', '나이': 21, '국어': 90, '영어': '88'},
#  {'이름': '논개', '나이': 22, '국어': 88, '영어': '85'},
#  {'이름': '계백', '나이': 20, '국어': 90, '영어': '84'},
#  {'이름': '관우', '나이': 19, '국어': 97, '영어': '96'},
#  {'이름': '장비', '나이': 20, '국어': 95, '영어': '-10'}]

# %% [markdown]
# ## 영어 결측치 처리

# %%
for d in data:
    if d["영어"] != "":
        print(d["영어"])
        print(type(d["영어"]))
# Out:
# 85
# <class 'str'>
# 90
# <class 'str'>
# 100
# <class 'str'>
# 82
# <class 'str'>
# 110
# <class 'str'>
# 88
# <class 'str'>
# 91
# <class 'str'>
# 89
# <class 'str'>
# 94
# <class 'str'>
# 86
# <class 'str'>
# 87
# <class 'str'>
# 92
# <class 'str'>
# 81
# <class 'str'>
# NaN
# <class 'str'>
# 88
# <class 'str'>
# 85
# <class 'str'>
# 84
# <class 'str'>
# 96
# <class 'str'>
# -10
# <class 'str'>

# %%
# 영어는 빈칸과 NaN이 모두 존재
for d in data:
    if d["영어"] != "" and d["영어"] != "NaN":
        d["영어"] = int(d["영어"])

# %%
# 빈칸 제외 int로 형변환 된거 확인
for d in data:
    if d["영어"] != "":
        print(d["영어"])
        print(type(d["영어"]))
# Out:
# 85
# <class 'int'>
# 90
# <class 'int'>
# 100
# <class 'int'>
# 82
# <class 'int'>
# 110
# <class 'int'>
# 88
# <class 'int'>
# 91
# <class 'int'>
# 89
# <class 'int'>
# 94
# <class 'int'>
# 86
# <class 'int'>
# 87
# <class 'int'>
# 92
# <class 'int'>
# 81
# <class 'int'>
# NaN
# <class 'str'>
# 88
# <class 'int'>
# 85
# <class 'int'>
# 84
# <class 'int'>
# 96
# <class 'int'>
# -10
# <class 'int'>

# %%
eng_total = 0
eng_count = 0

for d in data:
    if d["영어"] != "" and d["영어"] != "NaN":
        if 0 <= d["영어"] and d["영어"] <= 100:
            eng_total += d["영어"]
            eng_count += 1
print(eng_total, kor_count)
avg_eng = int(round(eng_total / eng_count,1))
print(avg_eng)

for d in data:
    if d["영어"] == "" or d["영어"] == "NaN":
        d["영어"] = avg_eng

data
# Out:
# 1418 16
# 88
# [{'이름': '홍길동', '나이': 20, '국어': 90, '영어': 85},
#  {'이름': '이순신', '나이': 21, '국어': 88, '영어': 90},
#  {'이름': '김유신', '나이': 27, '국어': 95, '영어': 100},
#  {'이름': '강감찬', '나이': 22, '국어': 90, '영어': 82},
#  {'이름': '유관순', '나이': 19, '국어': 100, '영어': 110},
#  {'이름': '안중근', '나이': 150, '국어': 85, '영어': 88},
#  {'이름': '윤봉길', '나이': 20, '국어': -5, '영어': 91},
#  {'이름': '신사임당', '나이': 21, '국어': 92, '영어': 88},
#  {'이름': '장보고', '나이': 18, '국어': 87, '영어': 89},
#  {'이름': '세종대왕', '나이': 23, '국어': 93, '영어': 94},
#  {'이름': '을지문덕', '나이': 20, '국어': 91, '영어': 86},
#  {'이름': '허준', '나이': 21, '국어': 89, '영어': 87},
#  {'이름': '김구', '나이': 22, '국어': 500, '영어': 92},
#  {'이름': '이황', '나이': 19, '국어': 84, '영어': 81},
#  {'이름': '이이', '나이': 20, '국어': 86, '영어': 88},
#  {'이름': '정약용', '나이': 21, '국어': 90, '영어': 88},
#  {'이름': '논개', '나이': 22, '국어': 88, '영어': 85},
#  {'이름': '계백', '나이': 20, '국어': 90, '영어': 84},
#  {'이름': '관우', '나이': 19, '국어': 97, '영어': 96},
#  {'이름': '장비', '나이': 20, '국어': 95, '영어': -10}]

# %% [markdown]
# ## 이상치 처리

# %%
# 나이 이상치 처리 평균
age_total = 0
age_count = 0
for d in data:
    age_Outlier = d["나이"]

    if age_Outlier > 100:
        print(d)
    
    if d["나이"] < 100:
        age_total += d["나이"]
        age_count += 1

print(age_total/age_count)
age_avg = int(round(age_total / age_count,0))

print(f"avg {age_avg}")

for d in data:
    if d["나이"] > 100:
        d["나이"] = age_avg

data
# Out:
# {'이름': '안중근', '나이': 150, '국어': 85, '영어': 88}
# 20.789473684210527
# avg 21
# [{'이름': '홍길동', '나이': 20, '국어': 90, '영어': 85},
#  {'이름': '이순신', '나이': 21, '국어': 88, '영어': 90},
#  {'이름': '김유신', '나이': 27, '국어': 95, '영어': 100},
#  {'이름': '강감찬', '나이': 22, '국어': 90, '영어': 82},
#  {'이름': '유관순', '나이': 19, '국어': 100, '영어': 110},
#  {'이름': '안중근', '나이': 21, '국어': 85, '영어': 88},
#  {'이름': '윤봉길', '나이': 20, '국어': -5, '영어': 91},
#  {'이름': '신사임당', '나이': 21, '국어': 92, '영어': 88},
#  {'이름': '장보고', '나이': 18, '국어': 87, '영어': 89},
#  {'이름': '세종대왕', '나이': 23, '국어': 93, '영어': 94},
#  {'이름': '을지문덕', '나이': 20, '국어': 91, '영어': 86},
#  {'이름': '허준', '나이': 21, '국어': 89, '영어': 87},
#  {'이름': '김구', '나이': 22, '국어': 500, '영어': 92},
#  {'이름': '이황', '나이': 19, '국어': 84, '영어': 81},
#  {'이름': '이이', '나이': 20, '국어': 86, '영어': 88},
#  {'이름': '정약용', '나이': 21, '국어': 90, '영어': 88},
#  {'이름': '논개', '나이': 22, '국어': 88, '영어': 85},
#  {'이름': '계백', '나이': 20, '국어': 90, '영어': 84},
#  {'이름': '관우', '나이': 19, '국어': 97, '영어': 96},
#  {'이름': '장비', '나이': 20, '국어': 95, '영어': -10}]

# %%
# 국어 이상치 처리 평균
kor_out_total = 0
kor_out_count = 0
for d in data:
    if d["국어"] < 0 or d["국어"] > 100:
        print(d)
    
    if d["국어"] > 0 and d["국어"] <= 100:
        kor_out_total += d["국어"]
        kor_out_count += 1

print(kor_out_total/kor_out_count)
kor_out_avg = int(round(kor_out_total / kor_out_count,0))

print(f"avg {kor_out_avg}")

for d in data:
    if d["국어"] > 100 or d["국어"] < 0:
        d["국어"] = kor_out_avg

data
# Out:
# {'이름': '윤봉길', '나이': 20, '국어': -5, '영어': 91}
# {'이름': '김구', '나이': 22, '국어': 500, '영어': 92}
# 90.55555555555556
# avg 91
# [{'이름': '홍길동', '나이': 20, '국어': 90, '영어': 85},
#  {'이름': '이순신', '나이': 21, '국어': 88, '영어': 90},
#  {'이름': '김유신', '나이': 27, '국어': 95, '영어': 100},
#  {'이름': '강감찬', '나이': 22, '국어': 90, '영어': 82},
#  {'이름': '유관순', '나이': 19, '국어': 100, '영어': 110},
#  {'이름': '안중근', '나이': 21, '국어': 85, '영어': 88},
#  {'이름': '윤봉길', '나이': 20, '국어': 91, '영어': 91},
#  {'이름': '신사임당', '나이': 21, '국어': 92, '영어': 88},
#  {'이름': '장보고', '나이': 18, '국어': 87, '영어': 89},
#  {'이름': '세종대왕', '나이': 23, '국어': 93, '영어': 94},
#  {'이름': '을지문덕', '나이': 20, '국어': 91, '영어': 86},
#  {'이름': '허준', '나이': 21, '국어': 89, '영어': 87},
#  {'이름': '김구', '나이': 22, '국어': 91, '영어': 92},
#  {'이름': '이황', '나이': 19, '국어': 84, '영어': 81},
#  {'이름': '이이', '나이': 20, '국어': 86, '영어': 88},
#  {'이름': '정약용', '나이': 21, '국어': 90, '영어': 88},
#  {'이름': '논개', '나이': 22, '국어': 88, '영어': 85},
#  {'이름': '계백', '나이': 20, '국어': 90, '영어': 84},
#  {'이름': '관우', '나이': 19, '국어': 97, '영어': 96},
#  {'이름': '장비', '나이': 20, '국어': 95, '영어': -10}]

# %%
# 영어 이상치 처리 평균
eng_out_total = 0
eng_out_count = 0
for d in data:
    if d["영어"] < 0 or d["영어"] > 100:
        print(d)
    
    if d["영어"] > 0 and d["영어"] <= 100:
        eng_out_total += d["영어"]
        eng_out_count += 1

print(eng_out_total/eng_out_count)
eng_out_avg = int(round(eng_out_total / eng_out_count,0))

print(f"avg {eng_out_avg}")

for d in data:
    if d["영어"] > 100 or d["영어"] < 0:
        d["영어"] = eng_out_avg

data
# Out:
# {'이름': '유관순', '나이': 19, '국어': 100, '영어': 110}
# {'이름': '장비', '나이': 20, '국어': 95, '영어': -10}
# 88.55555555555556
# avg 89
# [{'이름': '홍길동', '나이': 20, '국어': 90, '영어': 85},
#  {'이름': '이순신', '나이': 21, '국어': 88, '영어': 90},
#  {'이름': '김유신', '나이': 27, '국어': 95, '영어': 100},
#  {'이름': '강감찬', '나이': 22, '국어': 90, '영어': 82},
#  {'이름': '유관순', '나이': 19, '국어': 100, '영어': 89},
#  {'이름': '안중근', '나이': 21, '국어': 85, '영어': 88},
#  {'이름': '윤봉길', '나이': 20, '국어': 91, '영어': 91},
#  {'이름': '신사임당', '나이': 21, '국어': 92, '영어': 88},
#  {'이름': '장보고', '나이': 18, '국어': 87, '영어': 89},
#  {'이름': '세종대왕', '나이': 23, '국어': 93, '영어': 94},
#  {'이름': '을지문덕', '나이': 20, '국어': 91, '영어': 86},
#  {'이름': '허준', '나이': 21, '국어': 89, '영어': 87},
#  {'이름': '김구', '나이': 22, '국어': 91, '영어': 92},
#  {'이름': '이황', '나이': 19, '국어': 84, '영어': 81},
#  {'이름': '이이', '나이': 20, '국어': 86, '영어': 88},
#  {'이름': '정약용', '나이': 21, '국어': 90, '영어': 88},
#  {'이름': '논개', '나이': 22, '국어': 88, '영어': 85},
#  {'이름': '계백', '나이': 20, '국어': 90, '영어': 84},
#  {'이름': '관우', '나이': 19, '국어': 97, '영어': 96},
#  {'이름': '장비', '나이': 20, '국어': 95, '영어': 89}]

# %% [markdown]
# ## 파생 속성

# %%
# 총점 = (국어 + 영어)
for d in data:
    d["총점"] = d["국어"] + d["영어"]

data
# Out:
# [{'이름': '홍길동', '나이': 20, '국어': 90, '영어': 85, '총점': 175},
#  {'이름': '이순신', '나이': 21, '국어': 88, '영어': 90, '총점': 178},
#  {'이름': '김유신', '나이': 27, '국어': 95, '영어': 100, '총점': 195},
#  {'이름': '강감찬', '나이': 22, '국어': 90, '영어': 82, '총점': 172},
#  {'이름': '유관순', '나이': 19, '국어': 100, '영어': 89, '총점': 189},
#  {'이름': '안중근', '나이': 21, '국어': 85, '영어': 88, '총점': 173},
#  {'이름': '윤봉길', '나이': 20, '국어': 91, '영어': 91, '총점': 182},
#  {'이름': '신사임당', '나이': 21, '국어': 92, '영어': 88, '총점': 180},
#  {'이름': '장보고', '나이': 18, '국어': 87, '영어': 89, '총점': 176},
#  {'이름': '세종대왕', '나이': 23, '국어': 93, '영어': 94, '총점': 187},
#  {'이름': '을지문덕', '나이': 20, '국어': 91, '영어': 86, '총점': 177},
#  {'이름': '허준', '나이': 21, '국어': 89, '영어': 87, '총점': 176},
#  {'이름': '김구', '나이': 22, '국어': 91, '영어': 92, '총점': 183},
#  {'이름': '이황', '나이': 19, '국어': 84, '영어': 81, '총점': 165},
#  {'이름': '이이', '나이': 20, '국어': 86, '영어': 88, '총점': 174},
#  {'이름': '정약용', '나이': 21, '국어': 90, '영어': 88, '총점': 178},
#  {'이름': '논개', '나이': 22, '국어': 88, '영어': 85, '총점': 173},
#  {'이름': '계백', '나이': 20, '국어': 90, '영어': 84, '총점': 174},
#  {'이름': '관우', '나이': 19, '국어': 97, '영어': 96, '총점': 193},
#  {'이름': '장비', '나이': 20, '국어': 95, '영어': 89, '총점': 184}]

# %%
# 평균
for d in data:
    d["평균"] = round(d["총점"] / 2,1)

data
# Out:
# [{'이름': '홍길동', '나이': 20, '국어': 90, '영어': 85, '총점': 175, '평균': 87.5},
#  {'이름': '이순신', '나이': 21, '국어': 88, '영어': 90, '총점': 178, '평균': 89.0},
#  {'이름': '김유신', '나이': 27, '국어': 95, '영어': 100, '총점': 195, '평균': 97.5},
#  {'이름': '강감찬', '나이': 22, '국어': 90, '영어': 82, '총점': 172, '평균': 86.0},
#  {'이름': '유관순', '나이': 19, '국어': 100, '영어': 89, '총점': 189, '평균': 94.5},
#  {'이름': '안중근', '나이': 21, '국어': 85, '영어': 88, '총점': 173, '평균': 86.5},
#  {'이름': '윤봉길', '나이': 20, '국어': 91, '영어': 91, '총점': 182, '평균': 91.0},
#  {'이름': '신사임당', '나이': 21, '국어': 92, '영어': 88, '총점': 180, '평균': 90.0},
#  {'이름': '장보고', '나이': 18, '국어': 87, '영어': 89, '총점': 176, '평균': 88.0},
#  {'이름': '세종대왕', '나이': 23, '국어': 93, '영어': 94, '총점': 187, '평균': 93.5},
#  {'이름': '을지문덕', '나이': 20, '국어': 91, '영어': 86, '총점': 177, '평균': 88.5},
#  {'이름': '허준', '나이': 21, '국어': 89, '영어': 87, '총점': 176, '평균': 88.0},
#  {'이름': '김구', '나이': 22, '국어': 91, '영어': 92, '총점': 183, '평균': 91.5},
#  {'이름': '이황', '나이': 19, '국어': 84, '영어': 81, '총점': 165, '평균': 82.5},
#  {'이름': '이이', '나이': 20, '국어': 86, '영어': 88, '총점': 174, '평균': 87.0},
#  {'이름': '정약용', '나이': 21, '국어': 90, '영어': 88, '총점': 178, '평균': 89.0},
#  {'이름': '논개', '나이': 22, '국어': 88, '영어': 85, '총점': 173, '평균': 86.5},
#  {'이름': '계백', '나이': 20, '국어': 90, '영어': 84, '총점': 174, '평균': 87.0},
#  {'이름': '관우', '나이': 19, '국어': 97, '영어': 96, '총점': 193, '평균': 96.5},
#  {'이름': '장비', '나이': 20, '국어': 95, '영어': 89, '총점': 184, '평균': 92.0}]

# %% [markdown]
# ## 특성 추출

# %%
# 합격(평균 >= 60), 불합격(평균 < 60)
for d in data:
    if d["평균"] >= 60:
        d["합격 결과"] = "합격"
    elif d["평균"] < 60:
        d["합격 결과"] = "불합격"

data
# Out:
# [{'이름': '홍길동',
#   '나이': 20,
#   '국어': 90,
#   '영어': 85,
#   '총점': 175,
#   '평균': 87.5,
#   '합격 결과': '합격'},
#  {'이름': '이순신',
#   '나이': 21,
#   '국어': 88,
#   '영어': 90,
#   '총점': 178,
#   '평균': 89.0,
#   '합격 결과': '합격'},
#  {'이름': '김유신',
#   '나이': 27,
#   '국어': 95,
#   '영어': 100,
#   '총점': 195,
#   '평균': 97.5,
#   '합격 결과': '합격'},
#  {'이름': '강감찬',
#   '나이': 22,
#   '국어': 90,
#   '영어': 82,
#   '총점': 172,
#   '평균': 86.0,
#   '합격 결과': '합격'},
#  {'이름': '유관순',
#   '나이': 19,
#   '국어': 100,
#   '영어': 89,
#   '총점': 189,
#   '평균': 94.5,
#   '합격 결과': '합격'},
#  {'이름': '안중근',
#   '나이': 21,
#   '국어': 85,
#   '영어': 88,
#   '총점': 173,
#   '평균': 86.5,
#   '합격 결과': '합격'},
#  {'이름': '윤봉길',
#   '나이': 20,
#   '국어': 91,
#   '영어': 91,
#   '총점': 182,
#   '평균': 91.0,
#   '합격 결과': '합격'},
#  {'이름': '신사임당',
#   '나이': 21,
#   '국어': 92,
#   '영어': 88,
#   '총점': 180,
#   '평균': 90.0,
#   '합격 결과': '합격'},
#  {'이름': '장보고',
#   '나이': 18,
#   '국어': 87,
#   '영어': 89,
#   '총점': 176,
#   '평균': 88.0,
#   '합격 결과': '합격'},
#  {'이름': '세종대왕',
#   '나이': 23,
#   '국어': 93,
#   '영어': 94,
#   '총점': 187,
#   '평균': 93.5,
#   '합격 결과': '합격'},
#  {'이름': '을지문덕',
#   '나이': 20,
#   '국어': 91,
#   '영어': 86,
#   '총점': 177,
#   '평균': 88.5,
#   '합격 결과': '합격'},
#  {'이름': '허준',
#   '나이': 21,
#   '국어': 89,
#   '영어': 87,
#   '총점': 176,
#   '평균': 88.0,
#   '합격 결과': '합격'},
#  {'이름': '김구',
#   '나이': 22,
#   '국어': 91,
#   '영어': 92,
#   '총점': 183,
#   '평균': 91.5,
#   '합격 결과': '합격'},
#  {'이름': '이황',
#   '나이': 19,
#   '국어': 84,
#   '영어': 81,
#   '총점': 165,
#   '평균': 82.5,
#   '합격 결과': '합격'},
#  {'이름': '이이',
#   '나이': 20,
#   '국어': 86,
#   '영어': 88,
#   '총점': 174,
#   '평균': 87.0,
#   '합격 결과': '합격'},
#  {'이름': '정약용',
#   '나이': 21,
#   '국어': 90,
#   '영어': 88,
#   '총점': 178,
#   '평균': 89.0,
#   '합격 결과': '합격'},
#  {'이름': '논개',
#   '나이': 22,
#   '국어': 88,
#   '영어': 85,
#   '총점': 173,
#   '평균': 86.5,
#   '합격 결과': '합격'},
#  {'이름': '계백',
#   '나이': 20,
#   '국어': 90,
#   '영어': 84,
#   '총점': 174,
#   '평균': 87.0,
#   '합격 결과': '합격'},
#  {'이름': '관우',
#   '나이': 19,
#   '국어': 97,
#   '영어': 96,
#   '총점': 193,
#   '평균': 96.5,
#   '합격 결과': '합격'},
#  {'이름': '장비',
#   '나이': 20,
#   '국어': 95,
#   '영어': 89,
#   '총점': 184,
#   '평균': 92.0,
#   '합격 결과': '합격'}]

# %%
for d in data: # 모든 행에 반복문으로 순위를 구함
    
    rank = 1
    
    for other_student in data: # 전체를 반복
        if other_student["총점"] > d["총점"]:
            rank += 1

    # 순위 = 나보다 높은 학생 수 + 1
    d["순위"] = rank
    
data
# Out:
# [{'이름': '홍길동',
#   '나이': 20,
#   '국어': 90,
#   '영어': 85,
#   '총점': 175,
#   '평균': 87.5,
#   '합격 결과': '합격',
#   '순위': 14},
#  {'이름': '이순신',
#   '나이': 21,
#   '국어': 88,
#   '영어': 90,
#   '총점': 178,
#   '평균': 89.0,
#   '합격 결과': '합격',
#   '순위': 9},
#  {'이름': '김유신',
#   '나이': 27,
#   '국어': 95,
#   '영어': 100,
#   '총점': 195,
#   '평균': 97.5,
#   '합격 결과': '합격',
#   '순위': 1},
#  {'이름': '강감찬',
#   '나이': 22,
#   '국어': 90,
#   '영어': 82,
#   '총점': 172,
#   '평균': 86.0,
#   '합격 결과': '합격',
#   '순위': 19},
#  {'이름': '유관순',
#   '나이': 19,
#   '국어': 100,
#   '영어': 89,
#   '총점': 189,
#   '평균': 94.5,
#   '합격 결과': '합격',
#   '순위': 3},
#  {'이름': '안중근',
#   '나이': 21,
#   '국어': 85,
#   '영어': 88,
#   '총점': 173,
#   '평균': 86.5,
#   '합격 결과': '합격',
#   '순위': 17},
#  {'이름': '윤봉길',
#   '나이': 20,
#   '국어': 91,
#   '영어': 91,
#   '총점': 182,
#   '평균': 91.0,
#   '합격 결과': '합격',
#   '순위': 7},
#  {'이름': '신사임당',
#   '나이': 21,
#   '국어': 92,
#   '영어': 88,
#   '총점': 180,
#   '평균': 90.0,
#   '합격 결과': '합격',
#   '순위': 8},
#  {'이름': '장보고',
#   '나이': 18,
#   '국어': 87,
#   '영어': 89,
#   '총점': 176,
#   '평균': 88.0,
#   '합격 결과': '합격',
#   '순위': 12},
#  {'이름': '세종대왕',
#   '나이': 23,
#   '국어': 93,
#   '영어': 94,
#   '총점': 187,
#   '평균': 93.5,
#   '합격 결과': '합격',
#   '순위': 4},
#  {'이름': '을지문덕',
#   '나이': 20,
#   '국어': 91,
#   '영어': 86,
#   '총점': 177,
#   '평균': 88.5,
#   '합격 결과': '합격',
#   '순위': 11},
#  {'이름': '허준',
#   '나이': 21,
#   '국어': 89,
#   '영어': 87,
#   '총점': 176,
#   '평균': 88.0,
#   '합격 결과': '합격',
#   '순위': 12},
#  {'이름': '김구',
#   '나이': 22,
#   '국어': 91,
#   '영어': 92,
#   '총점': 183,
#   '평균': 91.5,
#   '합격 결과': '합격',
#   '순위': 6},
#  {'이름': '이황',
#   '나이': 19,
#   '국어': 84,
#   '영어': 81,
#   '총점': 165,
#   '평균': 82.5,
#   '합격 결과': '합격',
#   '순위': 20},
#  {'이름': '이이',
#   '나이': 20,
#   '국어': 86,
#   '영어': 88,
#   '총점': 174,
#   '평균': 87.0,
#   '합격 결과': '합격',
#   '순위': 15},
#  {'이름': '정약용',
#   '나이': 21,
#   '국어': 90,
#   '영어': 88,
#   '총점': 178,
#   '평균': 89.0,
#   '합격 결과': '합격',
#   '순위': 9},
#  {'이름': '논개',
#   '나이': 22,
#   '국어': 88,
#   '영어': 85,
#   '총점': 173,
#   '평균': 86.5,
#   '합격 결과': '합격',
#   '순위': 17},
#  {'이름': '계백',
#   '나이': 20,
#   '국어': 90,
#   '영어': 84,
#   '총점': 174,
#   '평균': 87.0,
#   '합격 결과': '합격',
#   '순위': 15},
#  {'이름': '관우',
#   '나이': 19,
#   '국어': 97,
#   '영어': 96,
#   '총점': 193,
#   '평균': 96.5,
#   '합격 결과': '합격',
#   '순위': 2},
#  {'이름': '장비',
#   '나이': 20,
#   '국어': 95,
#   '영어': 89,
#   '총점': 184,
#   '평균': 92.0,
#   '합격 결과': '합격',
#   '순위': 5}]

# %%
with open("score_result.csv", "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.DictWriter(f, fieldnames=data[0].keys())
    writer.writeheader()
    writer.writerows(data)

print("score_result.csv 저장 완료!")
# Out:
# score_result.csv 저장 완료!
