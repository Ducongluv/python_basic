# %%
name = "smith" # 시퀀스 타입은 길이가 있다 str은 시퀀스 타입
print(len(name))

# 인덱싱(오프셋)
print(name[2])

print(name[1:3])

# for문 반복
for ch in name:
    print(ch)

# 시퀀스[start:stop:step]
print(name[::-1])
# Out:
# 5
# i
# mi
# s
# m
# i
# t
# h
# htims

# %%
# 연결 연산
a = "py"
b = "thon"
print(a+b)
# Out:
# python

# %%
# 반복 연산
print("ha"*3)
# Out:
# hahaha

# %%
print("py" in "python")
print("java" in "python")
# Out:
# True
# False

# %%
# list는 가변 타입이기 때문에 변경 할 수 있다
nums = [1, 2, 3]
nums[0] = 100
print(nums)
# Out:
# [100, 2, 3]

# %%
print('python')
print("python")

# 여려줄 문자열

text = '''
안녕하세요
파이썬입니다
'''
print(text)

text = """
안녕하세요
파이썬입니다
"""
print(text)
# Out:
# python
# python
#
# 안녕하세요
# 파이썬입니다
#
#
# 안녕하세요
# 파이썬입니다

# %%
# 이스케이프 문자
# \n 줄바꿈, \t 탭
print("Hello\nPython")
# Out:
# Hello
# Python

# %%
# f-string : 문자열 안에 변수 표현식{변수} 사용
name = "Tom"
print(f"이름은 {name}이다")
# Out:
# 이름은 Tom이다

# %%
# 정수(int)와 문자열(str)은 바로 연결할 수 없기 때문에 str()로 문자열로 변환해야 한다.
year = 2026
month = 6
day = 22

date = str(year) + "-" + str(month) + "-" + str(day)

print(date)
# Out:
# 2026-6-22

# %%
# 숫자 변환 내장함수
a = "123"
b = "10"

print(a + b) # 12310

result = int(a) + int(b)

print(result)
# Out:
# 12310
# 133

# %%
s = "python"
print(dir(s))

print(s.upper())
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# PYTHON

# %%
# 대소문자 변환
text = "Python Programming"

print(text.upper())      # 모두 대문자
print(text.lower())      # 모두 소문자
print(text.capitalize()) # 첫 글자만 대문자
print(text.title())      # 각 단어 첫 글자 대문자
# Out:
# PYTHON PROGRAMMING
# python programming
# Python programming
# Python Programming

# %%
# 공백제거 단, 문자 사이의 공백은 제거가 안됨
text = "   Python   "

print(text.strip())   # 양쪽 공백 제거
print(text.lstrip())  # 왼쪽 공백 제거
print(text.rstrip())  # 오른쪽 공백 제거
# Out:
# Python
# Python
#    Python

# %%
# 문자열 검색
text = "Python Programming"

print(text.find("Pro"))
print(text.find("Java")) # 없는 글자는 -1 반환
print(text.startswith("Python")) # 성이 "김" name.startswith("김")
print(text.endswith("ing")) # 파일중에 한글 파일만 file.endswith(".hwp")
# Out:
# 7
# -1
# True
# True

# %%
# 문자열 치환
text = "I like Java"

print(text.replace("Java", "Python"))
# Out:
# I like Python

# %%
# 문자열 분리

data = "apple,banana,orange"

result = data.split(",")

print(result) # ['apple', 'banana', 'orange']
# Out:
# ['apple', 'banana', 'orange']

# %%
# 문자열 결합

fruits = ["apple", "banana", "orange"]

result = " + ".join(fruits)

print(result)
# Out:
# apple + banana + orange

# %%
# 문자열 개수 세기

text = "banana"

print(text.count("a")) # 3
print(text.count("na")) # 2
# Out:
# 3
# 2

# %%
# 문자열 판별

print("123".isdigit())      # 문자열이 숫자로만 구성되어 있는가?
print("Python".isalpha())   # 문자열이 영문자(또는 한글 등 문자)로만 구성되어 있는가?
print("Python123".isalnum()) # 문자열이 문자와 숫자로만 구성되어 있는가?
# Out:
# True
# True
# True

# %%
# 문자열 채우기 -> 요즘은 잘 안 쓰고 f-string 사용함

num = "100"

print(num.zfill(5))    # 전체 길이가 5가 되도록 왼쪽을 0으로 채움
print(num.center(10))  # 전체 길이가 10이 되도록 가운데 정렬
print(num.ljust(10))   # 전체 길이가 10이 되도록 왼쪽 정렬
print(num.rjust(10))   # 전체 길이가 10이 되도록 오른쪽 정렬
# Out:
# 00100
#    100
# 100
#        100

# %%
# 전화번호 연결

phone1 = "010"
phone2 = "1234"
phone3 = "5678"

phone = "-".join([phone1, phone2, phone3])

print(phone)
# Out:
# 010-1234-5678

# %%
# 이메일에서 아이디 추출

email = "python@test.com"

user_id = email.split("@")[0] # @를 기준으로 분리한 후 첫 번째 요소(인덱스 0) 추출

user_email = email.split("@")[1] # @를 기준으로 분리한 후 이메일.com 추출 [1], [-1]도 가능
print(user_id)
print(user_email)
# Out:
# python
# test.com

# %%
# 파일이름에서 확장자 추출

filename = "report.xlsx"

ext = filename.split(".")[-1] # # .을 기준으로 분리한 후 마지막 요소(인덱스 -1) 추출

print(ext)
# Out:
# xlsx

# %%
# 입출력
name = input("이름")
print(name)
# Out:
# 김주영

# %%
x = input("x입력")
y = input("y입력")

print(x+y)
print(int(x) + int(y))
# Out:
# 108
# 18

# %%
print("hi", "bye", sep= ", ")
print("hi", "bye", sep= "/")
print("hi", "bye", sep= "---")
# Out:
# hi, bye
# hi/bye
# hi---bye

# %%
# 3. 포맷 지정 출력



# 1) f-string(가장 많이 사용)

name = "Park"
age = 30

# f-string 기본 사용
print(f"이름: {name}, 나이: {age}")  # 변수 값을 문자열 안에 직접 삽입

# 소수점 자리수 지정
pi = 3.141592
print(f"{pi:.2f}")  # 소수점 둘째 자리까지 출력 → 3.14

# 자리수(폭) 지정
num = 7
print(f"{num:5}")   # 전체 5칸 확보, 오른쪽 정렬 → '    7'
print(f"{num:05}")  # 빈칸을 0으로 채움 → 00007
# Out:
# 이름: Park, 나이: 30
# 3.14
#     7
# 00007

# %%
# 2) format() 함수

# 기본 사용
print("이름: {}, 나이: {}".format("Park", 30))  # {} 순서대로 값 들어감

# 인덱스 사용
print("이름: {0}, 나이: {1}".format("Park", 30))  # 번호로 위치 지정

# 이름 지정
print("이름: {name}, 나이: {age}".format(name="Park", age=30))  
# 변수 이름으로 직접 지정 가능
# Out:
# 이름: Park, 나이: 30
# 이름: Park, 나이: 30
# 이름: Park, 나이: 30

# %%
# 3) % 연산자 

name = "Park"
age = 30

print("이름: %s, 나이: %d" % (name, age))  
# %s = 문자열, %d = 정수

pi = 3.141592
print("%.2f" % pi)  # 소수점 둘째 자리까지 출력 → 3.14
# Out:
# 이름: Park, 나이: 30
# 3.14

# %%
# 4) 문자열 정렬

# 왼쪽 정렬 (<), 오른쪽 정렬 (>), 가운데 정렬 (^)
print(f"{'Python':<10}")  # 왼쪽 정렬
print(f"{'Python':>10}")  # 오른쪽 정렬
print(f"{'Python':^10}")  # 가운데 정렬
# Out:
# Python
#     Python
#   Python
