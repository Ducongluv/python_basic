# %%
def add(a, b): # 변수 -> 매개변수
    return a + b

add2 = add

print(add)
print(add2)

print(add(1, 3)) # 함수 호출
r1 = add(10, 20)
print(r1 * 100)

r2 = add("abc", "xyz")
print(r2 * 3 )
# Out:
# <function add at 0x00000174257128E0>
# <function add at 0x00000174257128E0>
# 4
# 3000
# abcxyzabcxyzabcxyz

# %%
def test(a): # 지역변수 : a(매개변수)
    x = 100 + a
    print(x)

# print(a) 는 에러가 나온다 a는 test 함수 안에 만 있는 지역매개변수이기 때문
print(x)
# Out:
# 10

# %%
if True:
    x = 10

print(x)
# Out:
# 10
